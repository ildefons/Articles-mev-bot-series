# %%
import requests
# pretty print is used to print the output in the console in an easy to read format
from pprint import pprint
from datetime import datetime
from web3 import Web3
import pandas as pd
import matplotlib.pyplot as plt
import time
import re
import numpy as np

# %%
# transaction ids has to be checked in etherscan
node_url = "https://alien-sparkling-gadget.discover.quiknode.pro/ea1f5f2f5471b3a0525fa85dbfcfa27a5f90e25d/"
web3 = Web3(Web3.HTTPProvider(node_url))
tx = web3.eth.get_transaction('0xffe16a6ba847b9d189b6bb28686d1418bc1f4ef150800e4c48b5c02fe3555797')
block = tx.blockNumber
ts = web3.eth.get_block(block).timestamp
datetime.utcfromtimestamp(ts)
# Out:
# datetime.datetime(2023, 5, 21, 14, 41, 23)

# %%
from web3 import Web3
from web3 import AsyncHTTPProvider
from web3.eth import AsyncEth
import asyncio
import json
import math
import nest_asyncio
nest_asyncio.apply()

# %%
nodes = ['https://mainnet.infura.io/v3/174e045511c742af9cbe23f6bd053402',
         'https://mainnet.infura.io/v3/0731bcfffdb844daa0972c90e98da4e6',
         'https://mainnet.infura.io/v3/6d0c853857a249878418776d98bf732a']

# %%
# Define providers
w3 = Web3(Web3.HTTPProvider(nodes[0]))
providers = []
providersAsync = []
for node in nodes:
    providers.append(Web3.HTTPProvider(node))
    providersAsync.append(Web3(AsyncHTTPProvider(node), modules={"eth": (AsyncEth)}))

# %%
# Read factory contract addresses
# Uniswap V2 factory contract address
# contract_address = '0x5C69bEe701ef814a2B6a3EDD4B1652CB9cc5aA6f'
# SushiSwap factory contract address
# contract_address = '0xC0AEe478e3658e2610c5F7A4A2E1777cE9e4f2Ac'
with open("/home/ildefons/memeprj/Articles-mev-bot-series/Part 3/FactoriesV2.json", "r") as f:
    factories = json.load(f)

# %%
# Define the contract ABI
factory_abi = [
    {
        "anonymous": False,
        "inputs": [
            {
                "indexed": True,
                "internalType": "address",
                "name": "token0",
                "type": "address",
            },
            {
                "indexed": True,
                "internalType": "address",
                "name": "token1",
                "type": "address",
            },
            {
                "indexed": False,
                "internalType": "address",
                "name": "pair",
                "type": "address",
            },
            {
                "indexed": False,
                "internalType": "uint256",
                "name": "",
                "type": "uint256",
            },
        ],
        "name": "PairCreated",
        "type": "event",
    }
]

# %%
def getPairEvents(contract, fromBlock, toBlock):
    toBlockPrime = toBlock
    fetchCount = 0

    # Then, recursively fetch events in smaller time intervals
    def getEventsRecursive(contract, _from, _to):
        try:
            events = (
                contract.events.PairCreated()
                .create_filter(fromBlock=_from, toBlock=_to)
                .get_all_entries()
            )
            print("Found ", len(events), " events between blocks ", _from, " and ", _to)
            nonlocal fetchCount
            fetchCount += len(events)
            return events
        except ValueError:
            print("Too many events found between blocks ", _from, " and ", _to)
            midBlock = (_from + _to) // 2
            return getEventsRecursive(contract, _from, midBlock) + getEventsRecursive(
                contract, midBlock + 1, _to
            )

    return getEventsRecursive(contract, fromBlock, toBlockPrime)

# %%
# Fetch list of pools for each factory contract
pairDataList = []
for factoryName, factoryData in factories.items():
    events = getPairEvents(
        w3.eth.contract(address=factoryData["factory"], abi=factory_abi),
        0,
        w3.eth.block_number,
    )
    print(f"Found {len(events)} pools for {factoryName}")
    for e in events:
        pairDataList.append(
            {
                "token0": e["args"]["token0"],
                "token1": e["args"]["token1"],
                "pair": e["args"]["pair"],
                "factory": factoryName,
            }
        )
# Out:
# Too many events found between blocks  0  and  17749218
# Found  0  events between blocks  0  and  8874609
# Too many events found between blocks  8874610  and  17749218
# Too many events found between blocks  8874610  and  13311914
# Too many events found between blocks  8874610  and  11093262
# Found  0  events between blocks  8874610  and  9983936
# Too many events found between blocks  9983937  and  11093262
# Found  2933  events between blocks  9983937  and  10538599
# Too many events found between blocks  10538600  and  11093262
# Found  5052  events between blocks  10538600  and  10815931
# Found  8603  events between blocks  10815932  and  11093262
# Too many events found between blocks  11093263  and  13311914
# Too many events found between blocks  11093263  and  12202588
# Too many events found between blocks  11093263  and  11647925
# Found  8079  events between blocks  11093263  and  11370594
# Found  3654  events between blocks  11370595  and  11647925
# Found  4084  events between blocks  11647926  and  12202588
# Too many events found between blocks  12202589  and  13311914
# Too many events found between blocks  12202589  and  12757251
# Found  5016  events between blocks  12202589  and  12479920
# Found  9192  events between blocks  12479921  and  12757251
# Found  5905  events between blocks  12757252  and  13311914
# Too many events found between blocks  13311915  and  17749218
# Too many events found between blocks  13311915  and  15530566
# Too many events found between blocks  13311915  and  14421240
# Found  7661  events between blocks  13311915  and  13866577
# Found  6607  events between blocks  13866578  and  14421240
# Too many events found between blocks  14421241  and  15530566
# Too many events found between blocks  14421241  and  14975903
# Found  6218  events between blocks  14421241  and  14698572
# Found  4036  events between blocks  14698573  and  14975903
# Too many events found between blocks  14975904  and  15530566
# Found  7619  events between blocks  14975904  and  15253235
# Too many events found between blocks  15253236  and  15530566
# Found  5974  events between blocks  15253236  and  15391901
# Found  6095  events between blocks  15391902  and  15530566
# Too many events found between blocks  15530567  and  17749218
# Too many events found between blocks  15530567  and  16639892
# Too many events found between blocks  15530567  and  16085229
# Too many events found between blocks  15530567  and  15807898
# Found  6251  events between blocks  15530567  and  15669232
# Found  7979  events between blocks  15669233  and  15807898
# Too many events found between blocks  15807899  and  16085229
# Found  8419  events between blocks  15807899  and  15946564
# Found  4796  events between blocks  15946565  and  16085229
# Too many events found between blocks  16085230  and  16639892
# Too many events found between blocks  16085230  and  16362561
# Found  5523  events between blocks  16085230  and  16223895
# Found  5891  events between blocks  16223896  and  16362561
# Too many events found between blocks  16362562  and  16639892
# Found  5460  events between blocks  16362562  and  16501227
# Found  5271  events between blocks  16501228  and  16639892
# Too many events found between blocks  16639893  and  17749218
# Too many events found between blocks  16639893  and  17194555
# Found  9771  events between blocks  16639893  and  16917224
# Too many events found between blocks  16917225  and  17194555
# Found  5461  events between blocks  16917225  and  17055890
# Too many events found between blocks  17055891  and  17194555
# Found  5832  events between blocks  17055891  and  17125223
# Found  5771  events between blocks  17125224  and  17194555
# Too many events found between blocks  17194556  and  17749218
# Too many events found between blocks  17194556  and  17471887
# Too many events found between blocks  17194556  and  17333221
# Found  6606  events between blocks  17194556  and  17263888
# Found  7422  events between blocks  17263889  and  17333221
# Too many events found between blocks  17333222  and  17471887
# Found  6265  events between blocks  17333222  and  17402554
# Found  4760  events between blocks  17402555  and  17471887
# Too many events found between blocks  17471888  and  17749218
# Too many events found between blocks  17471888  and  17610553
# Found  4605  events between blocks  17471888  and  17541220
# Found  5446  events between blocks  17541221  and  17610553
# Too many events found between blocks  17610554  and  17749218
# Found  6489  events between blocks  17610554  and  17679886
# Found  6324  events between blocks  17679887  and  17749218
# Found 221070 pools for uniswapV2
# Found  3762  events between blocks  0  and  17749238
# Found 3762 pools for sushiswapV2
# Found  918  events between blocks  0  and  17749238
# Found 918 pools for shibaswapV2
# Found  99  events between blocks  0  and  17749238
# Found 99 pools for croswapV2
# Found  6  events between blocks  0  and  17749238
# Found 6 pools for convergenceV2
# Found  18  events between blocks  0  and  17749238
# Found 18 pools for bitberryV2
# Found  34  events between blocks  0  and  17749238
# Found 34 pools for dxswapV2
# Found  84  events between blocks  0  and  17749238
# Found 84 pools for equalizerV2
# Found  391  events between blocks  0  and  17749238
# Found 391 pools for pancakeswapV2
# Found  22  events between blocks  0  and  17749239
# Found 22 pools for fraxswapV2
# Found  13  events between blocks  0  and  17749239
# Found 13 pools for apeswapV2
# Found  37  events between blocks  0  and  17749239
# Found 37 pools for orionprotocolV2
# Found  79  events between blocks  0  and  17749239
# Found 79 pools for radioshackswapV2
# Found  5  events between blocks  0  and  17749239
# Found 5 pools for empireswapV2
# Found  37  events between blocks  0  and  17749239
# Found 37 pools for plasmaswapV2
# Found  7  events between blocks  0  and  17749239
# Found 7 pools for bambooswapV2
# Found  66  events between blocks  0  and  17749239
# Found 66 pools for linkswapV2
# Found  1  events between blocks  0  and  17749239
# Found 1 pools for saitaswapV2
# Found  10  events between blocks  0  and  17749239
# Found 10 pools for swipeswapV2
# Found  12  events between blocks  0  and  17749239
# Found 12 pools for kingswapV2
# Found  13  events between blocks  0  and  17749239
# Found 13 pools for capitalV2
# Found  10  events between blocks  0  and  17749239
# Found 10 pools for p00lsV2
# Found  41  events between blocks  0  and  17749239
# Found 41 pools for luaSwapV2
# Found  0  events between blocks  0  and  17749239
# Found 0 pools for wallstreetbetsV2

# %%
# %%
WETH = "0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2"
pair_pool_dict = {}
for pair_object in pairDataList:
    # Check for ETH (WETH) in the pair.
    pair = (pair_object['token0'], pair_object['token1'])
    if WETH not in pair:
        continue

    # Make sure the pair is referenced in the dictionary.
    if pair not in pair_pool_dict:
        pair_pool_dict[pair] = []

    # Add the pool to the list of pools that trade this pair.
    pair_pool_dict[pair].append(pair_object)

# Create the final dictionnary of pools that will be traded on.
pool_dict = {}
for pair, pool_list in pair_pool_dict.items():
    if len(pool_list) >= 2:
        pool_dict[pair] = pool_list

# %%
# %%
# Helper functions for calculating the optimal trade size
# Output of a single swap
def swap_output(x, a, b, fee=0.003):
    return b * (1 - a/(a + x*(1-fee)))

# Gross profit of two successive swaps
def trade_profit(x, reserves1, reserves2, fee=0.003):
    a1, b1 = reserves1
    a2, b2 = reserves2
    return swap_output(swap_output(x, a1, b1, fee), b2, a2, fee) - x

# Optimal input amount
def optimal_trade_size(reserves1, reserves2, fee=0.003):
    a1, b1 = reserves1
    a2, b2 = reserves2
    return (math.sqrt(a1*b1*a2*b2*(1-fee)**4 * (b1*(1-fee)+b2)**2) - a1*b2*(1-fee)*(b1*(1-fee)+b2)) / ((1-fee) * (b1*(1-fee) + b2))**2

# %%
# Fetch the reserves of each pool in pool_dict
to_fetch = [] # List of pool addresses for which reserves need to be fetched.
for pair, pool_list in pool_dict.items():
    for pair_object in pool_list:
        to_fetch.append(pair_object["pair"]) # Add the address of the pool
print(f"Fetching reserves of {len(to_fetch)} pools...")
# getReservesParallel() is from article 2 in the MEV bot series
reserveList = asyncio.get_event_loop().run_until_complete(getReservesParallel(to_fetch, providersAsync))
